# %%
from pymilvus import MilvusClient

client = MilvusClient("milvus_demo.db")
# Out:
# Open /home/ubuntu/Steps/milvus_demo.db failed, the file has been opened by another program
# Start local milvus failed
# Failed to create new connection using: afe2f9c51f474e049ee3a0e13de574a3
# ---------------------------------------------------------------------------
# ConnectionConfigException                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[1], line 3
#       1 from pymilvus import MilvusClient
# ----> 3 client = MilvusClient("milvus_demo.db")
#
# File ~/Steps/.venv/lib/python3.12/site-packages/pymilvus/milvus_client/milvus_client.py:58, in MilvusClient.__init__(self, uri, user, password, db_name, token, timeout, **kwargs)
#      46 """A client for the common Milvus use case.
#      47
#      48 This client attempts to hide away the complexity of using Pymilvus. In a lot ofcases what
#    (...)
#      56         to None.
#      57 """
# ---> 58 self._using = self._create_connection(
# ...
